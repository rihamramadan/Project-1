# %%
male = master_df[master_df["Gender"] == "Male"]
female = master_df[master_df["Gender"] == "Female"]
transfemale = master_df[master_df["Gender"] == "Transfemale"]
transmale = master_df[master_df["Gender"] == "Transmale"]
unknown = master_df[master_df["Gender"] == "Unknown"]


male_visit_count = male.groupby(["Viral Load Value"])["Visits"].mean()
male_visit_average = male.groupby(["Cd4 Test Value"])["Visits"].mean()
male_count = male.groupby(["ClientId"])["Viral Load Value"].mean()


female_visit_count = female.groupby(["Viral Load Value"])["Visits"].mean()
female_visit_average = female.groupby(["Cd4 Test Value"])["Visits"].mean()
female_count = female.groupby(["ClientId"])["Viral Load Value"].mean()


transfemale_visit_count = transfemale.groupby(["Viral Load Value"])["Visits"].mean()
transfemale_visit_average = transfemale.groupby(["Cd4 Test Value"])["Visits"].mean()
transfemale_count = female.groupby(["ClientId"])["Viral Load Value"].mean()

transmale_visit_count = transmale.groupby(["Viral Load Value"])["Visits"].mean()
transmale_visit_average = transmale.groupby(["Cd4 Test Value"])["Visits"].mean()
transmale_count = female.groupby(["ClientId"])["Viral Load Value"].mean()


unknown_visit_count = unknown.groupby(["Viral Load Value"])["Visits"].mean()
unknown_visit_average = unknown.groupby(["Cd4 Test Value"])["Visits"].mean()
unknown_count = unknown.groupby(["ClientId"])["Viral Load Value"].mean()



# Build the scatter plots for each city types
plt.scatter(male_visit_count, 
            male_visit_average, 
            s=10*male_count, c="coral", 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=1.0, label="Male")

plt.scatter(female_visit_count, 
            female_visit_average, 
            s=10*female_count, c="skyblue", 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=1.0, label="Female")

plt.scatter(transfemale_visit_count, 
            transfemale_visit_average, 
            s=10*transfemale_count, c="gold", 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=1.0, label="Transfemale")


plt.scatter(transmale_visit_count, 
            transmale_visit_average, 
            s=10*transmale_count, c="gold", 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=1.0, label="Transmale")


plt.scatter(unknown_visit_count, 
            unknown_visit_average, 
            s=10*unknown_count, c="gold", 
            edgecolor="black", linewidths=1, marker="o", 
            alpha=1.0, label="Other")

# Incorporate the other graph properties
plt.title("Visits by Gender")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.xlim((0,40))
plt.grid(True)

# Create a legend
lgnd = plt.legend(fontsize="small", mode="Expanded", 
                  numpoints=1, scatterpoints=1, 
                  loc="best", title="Gender", 
                  labelspacing=1.0)
lgnd.legendHandles[0]._sizes = [35]
lgnd.legendHandles[1]._sizes = [35]
lgnd.legendHandles[2]._sizes = [35]

# Incorporate a text label regarding circle size
plt.text(42, 35, "Note:\nCircle size correlates with driver count per city.")
